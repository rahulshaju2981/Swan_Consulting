# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('1 - Project Data.csv')

df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Reason         5174
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges         object
# Churn Label           object
# Churn Value            int64
# Churn Reason          object
# dtype: object

# %%
df['Total Charges'] = pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges          11
# Churn Label             0
# Churn Value             0
# Churn Reason         5174
# dtype: int64

# %%
df.loc[df['Tenure Months'] == 0]
# Out:
#       CustomerID  Count        Country       State            City  Zip Code  \
# 2234  4472-LVYGI      1  United States  California  San Bernardino     92408
# 2438  3115-CZMZD      1  United States  California    Independence     93526
# 2568  5709-LVOEQ      1  United States  California       San Mateo     94401
# 2667  4367-NUYAO      1  United States  California       Cupertino     95014
# 2856  1371-DWPAZ      1  United States  California        Redcrest     95569
# 4331  7644-OMVMY      1  United States  California     Los Angeles     90029
# 4687  3213-VVOLG      1  United States  California        Sun City     92585
# 5104  2520-SGTTA      1  United States  California      Ben Lomond     95005
# 5719  2923-ARZLG      1  United States  California        La Verne     91750
# 6772  4075-WKNIU      1  United States  California            Bell     90201
# 6840  2775-SEFEE      1  United States  California      Wilmington     90744
#
# ...

# %%
df['Total Charges'].fillna(0, inplace = True)
# Out:
# /var/folders/nn/b6p7_ncj4zn9kb5k0qsj4hxm0000gn/T/ipykernel_5158/103106840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Total Charges'].fillna(0, inplace = True)

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Reason         5174
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID            object
# Count                  int64
# Country               object
# State                 object
# City                  object
# Zip Code               int64
# Lat Long              object
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior Citizen        object
# Partner               object
# Dependents            object
# Tenure Months          int64
# Phone Service         object
# Multiple Lines        object
# Internet Service      object
# Online Security       object
# Online Backup         object
# Device Protection     object
# Tech Support          object
# Streaming TV          object
# Streaming Movies      object
# Contract              object
# Paperless Billing     object
# Payment Method        object
# Monthly Charges      float64
# Total Charges        float64
# Churn Label           object
# Churn Value            int64
# Churn Reason          object
# dtype: object

# %%
df['Churn Value'].value_counts()
# Out:
# Churn Value
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df.loc[df['Churn Value'] == 0 ].head()
# Out:
#       CustomerID  Count        Country       State         City  Zip Code  \
# 1869  7590-VHVEG      1  United States  California  Los Angeles     90001
# 1870  5575-GNVDE      1  United States  California  Los Angeles     90002
# 1871  7795-CFOCW      1  United States  California  Los Angeles     90004
# 1872  1452-KIOVK      1  United States  California  Los Angeles     90007
# 1873  6713-OKOMC      1  United States  California  Los Angeles     90008
#
#                     Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 1869   33.973616, -118.24902  33.973616 -118.249020  Female             No
# 1870  33.949255, -118.246978  33.949255 -118.246978    Male             No
# 1871  34.076259, -118.310715  34.076259 -118.310715    Male             No
# 1872   34.027337, -118.28515  34.027337 -118.285150    Male             No
# 1873  34.008293, -118.346766  34.008293 -118.346766  Female             No
#
# ...

# %%
df['Count'].value_counts()
# Out:
# Count
# 1    7043
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Reason'],
#       dtype='object')

# %%
df['Multiple Lines'].value_counts()
# Out:
# Multiple Lines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %% [markdown]
# * Keep lat, long and city
#     * Remove other locations
# * Gender is binary; Same as Senior Citizen, Partner and Dependents
# * Phone service and multiple lines are related
# * 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies' all related
# * Contract can be label encoded or OHE (transformed)
# * Paperless billing is binary
# * Payment method can be OHE
# * Churn Label and Churn Value are the same
# * Mapping on Churn Reason

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Total Charges  Churn Value
# count      7043.000000    7043.000000  7043.000000
# mean         64.761692    2279.734304     0.265370
# std          30.090047    2266.794470     0.441561
# min          18.250000       0.000000     0.000000
# 25%          35.500000     398.550000     0.000000
# ...

# %%
sns.boxplot(df['Total Charges'])
# Out:
# <Axes: ylabel='Total Charges'>

# %%
df.groupby('Churn Value')[['Monthly Charges']].mean()
# Out:
#              Monthly Charges
# Churn Value
# 0                  61.265124
# 1                  74.441332

# %%
sns.barplot(data = df.groupby('Churn Value')[['Monthly Charges']].mean(),
           x = 'Churn Value',
           y = 'Monthly Charges')

plt.show()

# %%
df.groupby('Churn Value')[['Total Charges']].mean()
# Out:
#              Total Charges
# Churn Value
# 0              2549.911442
# 1              1531.796094

# %%
sns.barplot(data = df.groupby('Churn Value')[['Total Charges']].mean(),
           x = 'Churn Value',
           y = 'Total Charges')

plt.show()

# %%
df['Internet Service'].value_counts()
# Out:
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df.groupby(['Internet Service', 'Churn Value'])[['Churn Value']].count()
# Out:
#                               Churn Value
# Internet Service Churn Value
# DSL              0                   1962
#                  1                    459
# Fiber optic      0                   1799
#                  1                   1297
# No               0                   1413
#                  1                    113

# %% [markdown]
# ### Internet Service / Churn Value Percentages
#
# * DSL:
#     * 81% have not churned (**0**)
#     * 19% have churned (**1**)
# * Fiber Optic:
#     * 58% have not churned (**0**)
#     * 42% have churned (**1**)
# * No:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)

# %%
sns.barplot(data = df.groupby('Internet Service')[['Total Charges']].mean(),
           x = 'Internet Service',
           y = 'Total Charges')

plt.show()

# %%
sns.barplot(data = df.groupby('Internet Service')[['Monthly Charges']].mean(),
           x = 'Internet Service',
           y = 'Monthly Charges')

plt.show()

# %%
df.groupby(['Contract', 'Churn Value'])[['Churn Value']].count()
# Out:
#                             Churn Value
# Contract       Churn Value
# Month-to-month 0                   2220
#                1                   1655
# One year       0                   1307
#                1                    166
# Two year       0                   1647
#                1                     48

# %% [markdown]
# ### Contract / Churn Value Percentages
#
# * Month to Month:
#     * 45% have not churned (**0**)
#     * 55% have churned (**1**)
# * One Year:
#     * 88% have not churned (**0**)
#     * 12% have churned (**1**)
# * Two Year:
#     * 97% have not churned (**0**)
#     * 3% have churned (**1**)

# %%
sns.barplot(data = df.groupby('Contract')[['Total Charges']].mean(),
           x = 'Contract',
           y = 'Total Charges')

plt.show()

# %%
df.groupby(['Senior Citizen', 'Churn Value'])[['Churn Value']].count()
# Out:
#                             Churn Value
# Senior Citizen Churn Value
# No             0                   4508
#                1                   1393
# Yes            0                    666
#                1                    476

# %% [markdown]
# ### Senior Citizen / Churn Value Percentages
#
# * No:
#     * 76% have not churned (**0**)
#     * 24% have churned (**1**)
# * Yes:
#     * 58% have not churned (**0**)
#     * 42% have churned (**1**)

# %%
df.groupby(['Partner', 'Churn Value'])[['Churn Value']].count()
# Out:
#                      Churn Value
# Partner Churn Value
# No      0                   2441
#         1                   1200
# Yes     0                   2733
#         1                    669

# %% [markdown]
# ### Partner / Churn Value Percentages
#
# * No:
#     * 67% have not churned (**0**)
#     * 33% have churned (**1**)
# * Yes:
#     * 80% have not churned (**0**)
#     * 20% have churned (**1**)

# %%
df.groupby(['Dependents', 'Churn Value'])[['Churn Value']].count()
# Out:
#                         Churn Value
# Dependents Churn Value
# No         0                   3653
#            1                   1763
# Yes        0                   1521
#            1                    106

# %% [markdown]
# ### Dependents / Churn Value Percentages
#
# * No:
#     * 67% have not churned (**0**)
#     * 33% have churned (**1**)
# * Yes:
#     * 93% have not churned (**0**)
#     * 7% have churned (**1**)

# %%
df.groupby(['Phone Service', 'Churn Value'])[['Churn Value']].count()
# Out:
#                            Churn Value
# Phone Service Churn Value
# No            0                    512
#               1                    170
# Yes           0                   4662
#               1                   1699

# %% [markdown]
# ### Phone Service / Churn Value Percentages
#
# * No:
#     * 75% have not churned (**0**)
#     * 25% have churned (**1**)
# * Yes:
#     * 73% have not churned (**0**)
#     * 27% have churned (**1**)

# %%
sns.barplot(data = df.groupby('Phone Service')[['Monthly Charges']].mean(),
           x = 'Phone Service',
           y = 'Monthly Charges')

plt.show()

# %%
df.groupby(['Multiple Lines', 'Churn Value'])[['Churn Value']].count()
# Out:
#                               Churn Value
# Multiple Lines   Churn Value
# No               0                   2541
#                  1                    849
# No phone service 0                    512
#                  1                    170
# Yes              0                   2121
#                  1                    850

# %% [markdown]
# ### Multiple Lines / Churn Value Percentages
#
# * No:
#     * 75% have not churned (**0**)
#     * 25% have churned (**1**)
# * No Phone Service:
#     * 75% have not churned (**0**)
#     * 25% have churned (**1**)
# * Yes:
#     * 71% have not churned (**0**)
#     * 29% have churned (**1**)

# %%
df.groupby(['Online Security', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Online Security     Churn Value
# No                  0                   2037
#                     1                   1461
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1724
#                     1                    295

# %% [markdown]
# ### Online Security / Churn Value Percentages
#
# * No:
#     * 58% have not churned (**0**)
#     * 42% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 85% have not churned (**0**)
#     * 15% have churned (**1**)

# %%
df.groupby(['Online Backup', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Online Backup       Churn Value
# No                  0                   1855
#                     1                   1233
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1906
#                     1                    523

# %% [markdown]
# ### Online Backup / Churn Value Percentages
#
# * No:
#     * 60% have not churned (**0**)
#     * 40% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 78% have not churned (**0**)
#     * 22% have churned (**1**)

# %%
df.groupby(['Device Protection', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Device Protection   Churn Value
# No                  0                   1884
#                     1                   1211
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1877
#                     1                    545

# %% [markdown]
# ### Device Protection / Churn Value Percentages
#
# * No:
#     * 61% have not churned (**0**)
#     * 39% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 77% have not churned (**0**)
#     * 23% have churned (**1**)

# %%
df.groupby(['Tech Support', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Tech Support        Churn Value
# No                  0                   2027
#                     1                   1446
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1734
#                     1                    310

# %% [markdown]
# ### Tech Support / Churn Value Percentages
#
# * No:
#     * 58% have not churned (**0**)
#     * 42% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 85% have not churned (**0**)
#     * 15% have churned (**1**)

# %%
df.groupby(['Streaming TV', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Streaming TV        Churn Value
# No                  0                   1868
#                     1                    942
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1893
#                     1                    814

# %% [markdown]
# ### Streaming TV / Churn Value Percentages
#
# * No:
#     * 66% have not churned (**0**)
#     * 34% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 70% have not churned (**0**)
#     * 30% have churned (**1**)

# %%
df.groupby(['Streaming Movies', 'Churn Value'])[['Churn Value']].count()
# Out:
#                                  Churn Value
# Streaming Movies    Churn Value
# No                  0                   1847
#                     1                    938
# No internet service 0                   1413
#                     1                    113
# Yes                 0                   1914
#                     1                    818

# %% [markdown]
# ### Streaming Movies / Churn Value Percentages
#
# * No:
#     * 66% have not churned (**0**)
#     * 34% have churned (**1**)
# * No Internet Service:
#     * 92% have not churned (**0**)
#     * 8% have churned (**1**)
# * Yes:
#     * 70% have not churned (**0**)
#     * 30% have churned (**1**)

# %%
sns.pairplot(df)

# %%
corre = df.corr(numeric_only = True)

sns.heatmap(data = corre,
            annot = True,
            vmin = -1,
            vmax = +1,
            mask = np.triu(corre),
            fmt = '0.01%'
            )

plt.show()

# %%
dfdf = df.copy()

# %%
def clean(df_original):
    df_original['Gender'] = df_original.Gender.map({'Female':0, 'Male':1})
    df_original['Senior Citizen'] = df_original['Senior Citizen'].map({'No':0, 'Yes':1})
    df_original['Partner'] = df_original.Partner.map({'No':0, 'Yes':1})
    df_original['Dependents'] = df_original.Dependents.map({'No':0, 'Yes':1})
    df_original['Contract'] = df_original.Contract.map({'Two year':2, 'Month-to-month':0, 'One year':1})
    # df_original['Churn Reason'] = df_original['Churn Reason'].fillna('np.nan')
    # df_original['Total Charges'] = pd.to_numeric(df_original['Total Charges'], errors='coerce')
    # df_original['Total Charges'].fillna(0, inplace=True)

    return df_original

# %%
clean(dfdf)
# Out:
#       CustomerID  Count        Country       State          City  Zip Code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
# ...

# %%
corre = dfdf.corr(numeric_only = True)
plt.figure(figsize = (10,10))

sns.heatmap(data = corre,
            annot = True,
            vmin = -1,
            vmax = +1,
            mask = np.triu(corre),
            fmt = '0.1%'
            )

plt.show()

# %%
# new_df = df.copy()

# %%
new_df = pd.get_dummies(new_df, columns = ['Multiple Lines'], prefix = 'ML', drop_first = False, dtype = int)

# %%
new_df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Paperless Billing             Payment Method Monthly Charges  Total Charges  \
# 0               Yes               Mailed check           53.85         108.15
# ...

# %%
new_df.drop(columns = ['ML_No phone service'], inplace = True)

# %%
new_df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.
